# %% [markdown]
# # NVDI AstroPi Challenge
#
#
# ```diff
# + Hi! We will write our study results in this notebook
# - Hola! Vamos a ir escribiendo en este cuaderno nuestro resultados de estudio
# ```

# %%
import cv2

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
os.chdir(os.path.join(et.io.HOME, "earth-analytics"))

# %%
color = ('b','g','r')

# %%
for i, c in enumerate(color):
    hist = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(hist, color = c)
    plt.xlim([0,256])
